# %% [markdown]
# <a href="https://colab.research.google.com/github/Khog123/AI-LAB/blob/main/KNN_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Step 1: Load dataset
data = load_iris()               # Load the Iris dataset
X = data.data                    # Features (inputs)
y = data.target                  # Labels (outputs)

# Step 2: Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=1, random_state=1
)

# Step 3: Create KNN model with k=3
model = KNeighborsClassifier(n_neighbors=3)

# Step 4: Train the model
model.fit(X_train, y_train)

# Step 5: Predict on both training and test data
y_train_pred = model.predict(X_train)   # Predictions for training data
y_test_pred = model.predict(X_test)     # Predictions for test data

# Step 6: Evaluate accuracy for both
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Step 7: Print the results
print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.959731543624161
# Testing Accuracy: 1.0

# %%
# Import libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Step 1: Load dataset
data = load_iris()               # Load the Iris dataset
X = data.data                    # Features (inputs)
y = data.target                  # Labels (outputs)

# Step 2: Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=100, random_state=-1
)

# Step 3: Create KNN model with k=3
model = KNeighborsClassifier(n_neighbors=3)

# Step 4: Train the model
model.fit(X_train, y_train)

# Step 5: Predict on both training and test data
y_train_pred = model.predict(X_train)   # Predictions for training data
y_test_pred = model.predict(X_test)     # Predictions for test data

# Step 6: Evaluate accuracy for both
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Step 7: Print the results
print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# /tmp/ipython-input-847561744.py in <cell line: 0>()
#      11
#      12 # Step 2: Split data into training and testing sets (80% train, 20% test)
# ---> 13 X_train, X_test, y_train, y_test = train_test_split(
#      14     X, y, test_size=100, random_state=-1
#      15 )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     204             params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
#     205
# --> 206             validate_parameter_constraints(
#     207                 parameter_constraints, params, caller_name=func.__qualname__
#     208             )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      96                 )
#      97
# ---> 98             raise InvalidParameterError(
#      99                 f"The {param_name!r} parameter of {caller_name} must be"
#     100                 f" {constraints_str}. Got {param_val!r} instead."
#
# InvalidParameterError: The 'random_state' parameter of train_test_split must be an int in the range [0, 4294967295], an instance of 'numpy.random.mtrand.RandomState' or None. Got -1 instead.

# %%
# Import libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Step 1: Load dataset
data = load_iris()               # Load the Iris dataset
X = data.data                    # Features (inputs)
y = data.target                  # Labels (outputs)

# Step 2: Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=2, random_state=21
)

# Step 3: Create KNN model with k=3
model = KNeighborsClassifier(n_neighbors=1)

# Step 4: Train the model
model.fit(X_train, y_train)

# Step 5: Predict on both training and test data
y_train_pred = model.predict(X_train)   # Predictions for training data
y_test_pred = model.predict(X_test)     # Predictions for test data

# Step 6: Evaluate accuracy for both
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Step 7: Print the results
print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 1.0

# %%
# Import libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Step 1: Load dataset
data = load_iris()               # Load the Iris dataset
X = data.data                    # Features (inputs)
y = data.target                  # Labels (outputs)

# Step 2: Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=20, random_state=50
)

# Step 3: Create KNN model with k=1
model = KNeighborsClassifier(n_neighbors=100)

# Step 4: Train the model
model.fit(X_train, y_train)

# Step 5: Predict on both training and test data
y_train_pred = model.predict(X_train)   # Predictions for training data
y_test_pred = model.predict(X_test)     # Predictions for test data

# Step 6: Evaluate accuracy for both
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Step 7: Print the results
print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.5076923076923077
# Testing Accuracy: 0.4
