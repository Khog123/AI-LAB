# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path = '/content/drive/MyDrive/AI/AI/data sheet.xlsx'


try:
    df = pd.read_excel(path)


    print("Shape of the DataFrame:")
    print(df.shape)

    print("\nColumns of the DataFrame:")
    print(df.columns)


    print("\nInformation about the DataFrame:")
    df.info()


    print("\nFirst 5 rows of the DataFrame:")
    display(df.head())

except FileNotFoundError:
    print(f"Error: The file was not found at {path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Shape of the DataFrame:
# (30, 10)
#
# Columns of the DataFrame:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
#
# Information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  26 non-null     object
#  4   Unnamed: 4  26 non-null     object
#  5   Unnamed: 5  26 non-null     object
#  6   Unnamed: 6  26 non-null     object
#  7   Unnamed: 7  26 non-null     object
#  8   Unnamed: 8  26 non-null     object
#  9   Unnamed: 9  20 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 2.5+ KB
#
# First 5 rows of the DataFrame:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0         NaN         NaN         NaN        NaN            NaN
# 1         NaN         NaN         NaN        NaN            NaN
# 2         NaN         NaN         NaN        NaN            NaN
# 3         NaN         NaN         NaN        NaN            NaN
# 4         NaN         NaN         NaN          #  Title (short)
#
#        Unnamed: 5  Unnamed: 6         Unnamed: 7   Unnamed: 8    Unnamed: 9
# 0             NaN         NaN                NaN          NaN           NaN
# 1             NaN         NaN                NaN          NaN           NaN
# 2             NaN         NaN                NaN          NaN           NaN
# 3             NaN         NaN                NaN          NaN           NaN
# 4  Authors (year)  Dataset(s)  Method / Approach  Key finding  Eval metrics

# %%
# Inspect the first few rows to identify the correct header row
display(df.head(10))
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0         NaN         NaN         NaN        NaN
# 1         NaN         NaN         NaN        NaN
# 2         NaN         NaN         NaN        NaN
# 3         NaN         NaN         NaN        NaN
# 4         NaN         NaN         NaN          #
# 5         NaN         NaN         NaN          1
# 6         NaN         NaN         NaN          2
# 7         NaN         NaN         NaN          3
# 8         NaN         NaN         NaN          4
# 9         NaN         NaN         NaN          5
#
#                                     Unnamed: 4                    Unnamed: 5  \
# 0                                          NaN                           NaN
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                Title (short)                Authors (year)
# 5                      UNSW-NB15 dataset paper  N. Moustafa & J. Slay (2015)
# 6               CICIDS2017 dataset description  I. Sharafaldin et al. (2018)
# 7                      CSE-CIC-IDS2018 dataset              UNB / CIC (2018)
# 8              KDD Cup 1999 / DARPA evaluation        Lippmann et al. (2000)
# 9  A Detailed Analysis of KDD Cup 99 (NSL-KDD)       Tavallaee et al. (2009)
#
#         Unnamed: 6                             Unnamed: 7  \
# 0              NaN                                    NaN
# 1              NaN                                    NaN
# 2              NaN                                    NaN
# 3              NaN                                    NaN
# 4       Dataset(s)                      Method / Approach
# 5        UNSW-NB15  Dataset creation / feature extraction
# 6       CICIDS2017          Dataset creation (PCAP→flows)
# 7  CSE-CIC-IDS2018                       Dataset creation
# 8    DARPA / KDD99              Evaluation / benchmarking
# 9  KDD99 → NSL-KDD     Dataset critique / propose NSL-KDD
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                        Key finding
# 5  Modern, realistic labeled flows; addresses KDD...
# 6  Contains benign + up-to-date attacks; widely u...
# 7  Large multi-scenario dataset (7 attack scenari...
# 8  Historical benchmark; later shown to have redu...
# 9  Identifies redundancy & skew; proposes NSL-KDD...
#
#                                           Unnamed: 9
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       Eval metrics
# 5                  N/A (dataset paper). UNSW Sites+1
# 6                        N/A (dataset). SciTePress+1
# 7       N/A (dataset). University of New Brunswick+1
# 8  Evaluation metrics; historical. archive.ll.mit...
# 9            N/A (dataset critique). ee.torontomu.ca

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path = '/content/drive/MyDrive/AI/Test_data.csv'

df = pd.read_csv(path)
#df.head()
print(df.shape)
print(df.columns)
print(df.describe())
#df.Info
# Out:
# (22544, 41)
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate'],
#       dtype='object')
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  22544.000000  2.254400e+04  2.254400e+04  22544.000000    22544.000000
# mean     218.859076  1.039545e+04  2.056019e+03      0.000311        0.008428
# std     1407.176612  4.727864e+05  2.121930e+04      0.017619        0.142599
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  5.400000e+01  4.600000e+01      0.000000        0.000000
# 75%        0.000000  2.870000e+02  6.010000e+02      0.000000        0.000000
# max    57715.000000  6.282565e+07  1.345927e+06      1.000000        3.000000
#
#              urgent           hot  num_failed_logins     logged_in  \
# count  22544.000000  22544.000000       22544.000000  22544.000000
# mean       0.000710      0.105394           0.021647      0.442202
# std        0.036473      0.928428           0.150328      0.496659
# min        0.000000      0.000000           0.000000      0.000000
# 25%        0.000000      0.000000           0.000000      0.000000
# 50%        0.000000      0.000000           0.000000      0.000000
# 75%        0.000000      0.000000           0.000000      1.000000
# max        3.000000    101.000000           4.000000      1.000000
#
#        num_compromised  ...  dst_host_count  dst_host_srv_count  \
# count     22544.000000  ...    22544.000000        22544.000000
# mean          0.119899  ...      193.869411          140.750532
# std           7.269597  ...       94.035663          111.783972
# min           0.000000  ...        0.000000            0.000000
# 25%           0.000000  ...      121.000000           15.000000
# 50%           0.000000  ...      255.000000          168.000000
# 75%           0.000000  ...      255.000000          255.000000
# max         796.000000  ...      255.000000          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count            22544.000000            22544.000000
# mean                 0.608722                0.090540
# std                  0.435688                0.220717
# min                  0.000000                0.000000
# 25%                  0.070000                0.000000
# 50%                  0.920000                0.010000
# 75%                  1.000000                0.060000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                 22544.000000                 22544.000000
# mean                      0.132261                     0.019638
# std                       0.306268                     0.085394
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.030000                     0.010000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count          22544.000000              22544.000000          22544.000000
# mean               0.097814                  0.099426              0.233385
# std                0.273139                  0.281866              0.387229
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                0.000000                  0.000000              0.360000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count              22544.000000
# mean                   0.226683
# std                    0.400875
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.170000
# max                    1.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# # Task
# Generate a line chart, a histogram or distribution plot, and a bar chart using Matplotlib based on the columns of the dataframe.

# %% [markdown]
# ## Identify columns for plotting
#
# ### Subtask:
# Determine which columns from the DataFrame are suitable for creating line, histogram/distribution, and bar charts based on their data types and content.

# %% [markdown]
# **Reasoning**:
# Inspect the data types and a few unique values of each column to determine suitability for different plot types.

# %%
print(df.dtypes)
for column in df.columns:
    print(f"\nColumn: {column}")
    print(f"Number of unique values: {df[column].nunique()}")
    if df[column].nunique() < 20: # Display unique values for columns with few unique values
        print(f"Unique values: {df[column].unique()}")
    else:
        print(f"First 5 unique values: {df[column].unique()[:5]}")
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# srv_serror_rate                float64
# rerror_rate                    float64
# srv_rerror_rate                float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# srv_diff_host_rate             float64
# dst_host_count                   int64
# dst_host_srv_count               int64
# dst_host_same_srv_rate         float64
# dst_host_diff_srv_rate         float64
# dst_host_same_src_port_rate    float64
# dst_host_srv_diff_host_rate    float64
# dst_host_serror_rate           float64
# dst_host_srv_serror_rate       float64
# dst_host_rerror_rate           float64
# dst_host_srv_rerror_rate       float64
# dtype: object
#
# Column: duration
# Number of unique values: 624
# First 5 unique values: [  0   2   1  37 805]
#
# Column: protocol_type
# Number of unique values: 3
# Unique values: ['tcp' 'icmp' 'udp']
#
# Column: service
# Number of unique values: 64
# First 5 unique values: ['private' 'ftp_data' 'eco_i' 'telnet' 'http']
#
# Column: flag
# Number of unique values: 11
# Unique values: ['REJ' 'SF' 'RSTO' 'S0' 'RSTR' 'SH' 'S3' 'S2' 'S1' 'RSTOS0' 'OTH']
#
# Column: src_bytes
# Number of unique values: 1149
# First 5 unique values: [    0 12983    20   267  1022]
#
# Column: dst_bytes
# Number of unique values: 3650
# First 5 unique values: [    0    15 14515   387   174]
#
# Column: land
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: wrong_fragment
# Number of unique values: 3
# Unique values: [0 1 3]
#
# Column: urgent
# Number of unique values: 4
# Unique values: [0 1 2 3]
#
# Column: hot
# Number of unique values: 16
# Unique values: [  0   4   2   1   7   6   5   3  22  10  11  19 101  18  15  30]
#
# Column: num_failed_logins
# Number of unique values: 5
# Unique values: [0 1 3 2 4]
#
# Column: logged_in
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: num_compromised
# Number of unique values: 23
# First 5 unique values: [  0   1 611   2   8]
#
# Column: root_shell
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: su_attempted
# Number of unique values: 3
# Unique values: [0 2 1]
#
# Column: num_root
# Number of unique values: 20
# First 5 unique values: [  0   1 684   4  23]
#
# Column: num_file_creations
# Number of unique values: 9
# Unique values: [  0   4   2   1   3 100   5   6   7]
#
# Column: num_shells
# Number of unique values: 4
# Unique values: [0 1 2 5]
#
# Column: num_access_files
# Number of unique values: 5
# Unique values: [0 1 3 2 4]
#
# Column: num_outbound_cmds
# Number of unique values: 1
# Unique values: [0]
#
# Column: is_host_login
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: is_guest_login
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: count
# Number of unique values: 495
# First 5 unique values: [229 136   1   4  33]
#
# Column: srv_count
# Number of unique values: 457
# First 5 unique values: [10  1 65  8  4]
#
# Column: serror_rate
# Number of unique values: 88
# First 5 unique values: [0.   1.   0.05 0.03 0.15]
#
# Column: srv_serror_rate
# Number of unique values: 82
# First 5 unique values: [0.   0.12 1.   0.05 0.33]
#
# Column: rerror_rate
# Number of unique values: 90
# First 5 unique values: [1.   0.   0.92 0.83 0.99]
#
# Column: srv_rerror_rate
# Number of unique values: 93
# First 5 unique values: [1.   0.   0.5  0.67 0.44]
#
# Column: same_srv_rate
# Number of unique values: 75
# First 5 unique values: [0.04 0.01 1.   0.02 0.09]
#
# Column: diff_srv_rate
# Number of unique values: 99
# First 5 unique values: [0.06 0.   0.07 0.05 0.38]
#
# Column: srv_diff_host_rate
# Number of unique values: 84
# First 5 unique values: [0.   1.   0.75 0.04 0.11]
#
# Column: dst_host_count
# Number of unique values: 256
# First 5 unique values: [255 134   3  29 155]
#
# Column: dst_host_srv_count
# Number of unique values: 256
# First 5 unique values: [ 10   1  86  57 255]
#
# Column: dst_host_same_srv_rate
# Number of unique values: 101
# First 5 unique values: [0.04 0.   0.61 1.   0.31]
#
# Column: dst_host_diff_srv_rate
# Number of unique values: 101
# First 5 unique values: [0.06 0.04 0.   0.17 0.72]
#
# Column: dst_host_same_src_port_rate
# Number of unique values: 101
# First 5 unique values: [0.   0.61 1.   0.03 0.01]
#
# Column: dst_host_srv_diff_host_rate
# Number of unique values: 58
# First 5 unique values: [0.   0.02 0.28 0.03 0.04]
#
# Column: dst_host_serror_rate
# Number of unique values: 99
# First 5 unique values: [0.   0.01 0.69 1.   0.05]
#
# Column: dst_host_srv_serror_rate
# Number of unique values: 101
# First 5 unique values: [0.   0.01 0.95 0.77 1.  ]
#
# Column: dst_host_rerror_rate
# Number of unique values: 101
# First 5 unique values: [1.   0.   0.83 0.72 0.02]
#
# Column: dst_host_srv_rerror_rate
# Number of unique values: 100
# First 5 unique values: [1.   0.   0.71 0.04 0.02]

# %% [markdown]
# ## Generate code for line chart
#
# ### Subtask:
# Create a code cell to generate a line chart using Matplotlib, using the selected columns.

# %% [markdown]
# **Reasoning**:
# Generate a line chart for the 'src_bytes' column against the DataFrame index.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['src_bytes'])
plt.xlabel('Index')
plt.ylabel('src_bytes')
plt.title('Line Chart of src_bytes')
plt.show()

# %% [markdown]
# ## Generate code for histogram/distribution plot
#
# ### Subtask:
# Create a code cell to generate a histogram or a similar distribution plot using Matplotlib, using the selected columns.

# %% [markdown]
# **Reasoning**:
# Generate a histogram for the 'duration' column to visualize its distribution.

# %%
plt.figure()
plt.hist(df['duration'])
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.title('Distribution of Duration')
plt.show()

# %% [markdown]
# ## Generate code for bar chart
#
# ### Subtask:
# Create a code cell to generate a bar chart using Matplotlib, using the selected columns.

# %% [markdown]
# **Reasoning**:
# Calculate the value counts for 'protocol_type' and generate a bar chart based on these counts as instructed.

# %%
plt.figure()
protocol_counts = df['protocol_type'].value_counts()
plt.bar(protocol_counts.index, protocol_counts.values)
plt.xlabel('Protocol Type')
plt.ylabel('Count')
plt.title('Distribution of Protocol Types')
plt.show()

# %% [markdown]
# ## Explain the generated code
#
# ### Subtask:
# Provide explanations for the code used to generate the line chart, histogram, and bar chart.

# %% [markdown]
# **Reasoning**:
# Explain the code for generating the line chart, histogram, and bar chart as requested in the instructions.

# %%
print("Explanation for Line Chart ('Line Chart of src_bytes'):")
print("plt.figure(figsize=(12, 6)): This line creates a new figure for the plot with a specified size of 12 inches in width and 6 inches in height. This helps in adjusting the overall size of the plot.")
print("plt.plot(df.index, df['src_bytes']): This is the core line for generating the line chart. It plots the values from the 'src_bytes' column against the DataFrame's index. The DataFrame index is used as the x-axis because there isn't a specific time-series column, representing the order of the data points. 'src_bytes' values are plotted on the y-axis, showing how the source bytes change across the dataset's entries.")
print("plt.xlabel('Index'): This sets the label for the x-axis to 'Index'.")
print("plt.ylabel('src_bytes'): This sets the label for the y-axis to 'src_bytes'.")
print("plt.title('Line Chart of src_bytes'): This sets the title of the line chart to 'Line Chart of src_bytes'.")
print("plt.show(): This displays the generated plot.")

print("\nExplanation for Histogram ('Distribution of Duration'):")
print("plt.figure(): This creates a new figure for the histogram.")
print("plt.hist(df['duration']): This generates the histogram. It takes the 'duration' column as input and automatically divides the data into bins, counting how many values fall into each bin. The height of each bar in the histogram represents the frequency (count) of data points within that bin.")
print("plt.xlabel('Duration'): This sets the label for the x-axis to 'Duration', representing the range of values for the duration of connections.")
print("plt.ylabel('Frequency'): This sets the label for the y-axis to 'Frequency', indicating the number of data points that fall within each duration range bin.")
print("plt.title('Distribution of Duration'): This sets the title of the histogram to 'Distribution of Duration'.")
print("plt.show(): This displays the generated plot. From this histogram, we can understand the distribution of connection durations, identifying common durations and the spread of the data.")

print("\nExplanation for Bar Chart ('Distribution of Protocol Types'):")
print("plt.figure(): This creates a new figure for the bar chart.")
print("protocol_counts = df['protocol_type'].value_counts(): This line calculates the frequency of each unique value in the 'protocol_type' column. It returns a pandas Series where the index represents the unique protocol types and the values are their corresponding counts. This is the data that will be used to create the bars.")
print("plt.bar(protocol_counts.index, protocol_counts.values): This is the core line for generating the bar chart. It creates bars where the x-positions are the unique protocol types (from the index of protocol_counts) and the height of each bar is the count of that protocol type (from the values of protocol_counts).")
print("plt.xlabel('Protocol Type'): This sets the label for the x-axis to 'Protocol Type'.")
print("plt.ylabel('Count'): This sets the label for the y-axis to 'Count', representing the number of occurrences for each protocol type.")
print("plt.title('Distribution of Protocol Types'): This sets the title of the bar chart to 'Distribution of Protocol Types'. This visualization helps in understanding the most frequent protocol types in the dataset.")
print("plt.show(): This displays the generated plot.")
# Out:
# Explanation for Line Chart ('Line Chart of src_bytes'):
# plt.figure(figsize=(12, 6)): This line creates a new figure for the plot with a specified size of 12 inches in width and 6 inches in height. This helps in adjusting the overall size of the plot.
# plt.plot(df.index, df['src_bytes']): This is the core line for generating the line chart. It plots the values from the 'src_bytes' column against the DataFrame's index. The DataFrame index is used as the x-axis because there isn't a specific time-series column, representing the order of the data points. 'src_bytes' values are plotted on the y-axis, showing how the source bytes change across the dataset's entries.
# plt.xlabel('Index'): This sets the label for the x-axis to 'Index'.
# plt.ylabel('src_bytes'): This sets the label for the y-axis to 'src_bytes'.
# plt.title('Line Chart of src_bytes'): This sets the title of the line chart to 'Line Chart of src_bytes'.
# plt.show(): This displays the generated plot.
#
# Explanation for Histogram ('Distribution of Duration'):
# plt.figure(): This creates a new figure for the histogram.
# plt.hist(df['duration']): This generates the histogram. It takes the 'duration' column as input and automatically divides the data into bins, counting how many values fall into each bin. The height of each bar in the histogram represents the frequency (count) of data points within that bin.
# plt.xlabel('Duration'): This sets the label for the x-axis to 'Duration', representing the range of values for the duration of connections.
# plt.ylabel('Frequency'): This sets the label for the y-axis to 'Frequency', indicating the number of data points that fall within each duration range bin.
# plt.title('Distribution of Duration'): This sets the title of the histogram to 'Distribution of Duration'.
# plt.show(): This displays the generated plot. From this histogram, we can understand the distribution of connection durations, identifying common durations and the spread of the data.
#
# Explanation for Bar Chart ('Distribution of Protocol Types'):
# plt.figure(): This creates a new figure for the bar chart.
# protocol_counts = df['protocol_type'].value_counts(): This line calculates the frequency of each unique value in the 'protocol_type' column. It returns a pandas Series where the index represents the unique protocol types and the values are their corresponding counts. This is the data that will be used to create the bars.
# plt.bar(protocol_counts.index, protocol_counts.values): This is the core line for generating the bar chart. It creates bars where the x-positions are the unique protocol types (from the index of protocol_counts) and the height of each bar is the count of that protocol type (from the values of protocol_counts).
# plt.xlabel('Protocol Type'): This sets the label for the x-axis to 'Protocol Type'.
# plt.ylabel('Count'): This sets the label for the y-axis to 'Count', representing the number of occurrences for each protocol type.
# plt.title('Distribution of Protocol Types'): This sets the title of the bar chart to 'Distribution of Protocol Types'. This visualization helps in understanding the most frequent protocol types in the dataset.
# plt.show(): This displays the generated plot.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains a mix of numerical (`int64`, `float64`) and categorical (`object`) columns.
# *   Several columns have a small number of unique values (e.g., `protocol_type`, `land`, `logged_in`), making them suitable for bar charts.
# *   Numerical columns like `duration`, `src_bytes`, and `dst_bytes` have a wide range of unique values, suitable for histograms.
# *   A line chart of `src_bytes` was generated against the DataFrame index as a proxy for a time-series plot.
# *   A histogram of the `duration` column was successfully created, showing the distribution of connection durations.
# *   A bar chart showing the distribution of `protocol_type` was generated, indicating the frequency of each protocol type.
#
# ### Insights or Next Steps
#
# *   The generated plots provide initial visual insights into the distribution of numerical features and the frequency of categorical features.
# *   Further analysis could involve exploring the relationships between different columns using scatter plots or other multivariate visualizations.
